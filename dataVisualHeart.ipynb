# %%
# Prepare dataset for environment
# %pip install ucimlrepo
# %pip install kneed

# Import packages to be used
from ucimlrepo import fetch_ucirepo 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# import plotly.graph_objects as go

# %%
######### Heart Disease ##############
# Multivariate; Classification
  
# fetch dataset 
heart_disease = fetch_ucirepo(id=45) 
  
# data (as pandas dataframes) 
x = heart_disease.data.features 
y = heart_disease.data.targets 
  
# metadata 
# print(heart_disease.metadata)

# %%
####### Data Cleaning ########
# read on data cleaning checks and good practices 

# Convert Date and Time column to datetime64 data type/
# df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
#pd.to_timedelta(df['Time'], errors='coerce')
df['Time'] = pd.to_datetime(df['Time'], format="%H:%M:%S", errors='coerce')

# Convert rest of columns to float64 data type.
for column in df.columns[2:]:
    df[column] = pd.to_numeric(df[column], errors='coerce')
print(df.dtypes)

# Check for missing values
naCheck = df.notna().values.any()
print(naCheck)

df.info()

# naCheck2 = 
# np.isinf(df).any().any()
# np.any(np.isnan(df))
# print(naCheck2)

# df_new = df[np.isfinite(df).all(1)]
    # isfinite is not definite for certain input types
# print(df_new)

# Fill empty values
# df[2:8].fillna(0.0)

print(df.columns)
print(df[:])
